# %%
from model import ModelWrapper

# %%
wrap = ModelWrapper()

# %%
from PIL import Image

# Загрузка изображения
image_path = "test.jpg"
image = Image.open(image_path)

# %%
image_path2 = "test2.jpg"
image2 = Image.open(image_path2)

# %%
image_path3 = "test3.jpg"
image3 = Image.open(image_path3)

# %%
from matplotlib import pyplot as plt 

# helper function for data visualization
def visualize(**images):
    """
    Plot images in one row
    """
    n_images = len(images)
    plt.figure(figsize=(20,8))
    for idx, (name, image) in enumerate(images.items()):
        plt.subplot(1, n_images, idx + 1)
        plt.xticks([]); 
        plt.yticks([])
        # get title from the parameter names
        plt.title(name.replace('_',' ').title(), fontsize=20)
        plt.imshow(image, cmap='gray')
    plt.show()

# %%
visualize(image = image, image2 = image2, image3 = image3)

# %%
text1 = 'Banana'
text2 = 'Girl, anime'
text3 = 'Animals'

# %%
mat = wrap.get_image_similarity([image, image2, image3])
mat
# Out:
# tensor([[1.0000, 0.5475, 0.4852],
#         [0.5475, 1.0000, 0.5583],
#         [0.4852, 0.5583, 1.0000]], device='cuda:0', grad_fn=<MmBackward0>)
